# %% [markdown]
# # Tutorial

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C,S = np.cos(X), np.sin(X)

# %%
plt.plot(X,C)
plt.plot(X,S)

plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
plt.figure(figsize=(8,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")

# Set x limits
plt.xlim(-4.0,4.0)

# Set x ticks
plt.xticks(np.linspace(-4,4,9,endpoint=True))

# Set y limits
plt.ylim(-1.0,1.0)

# Set y ticks
plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)
# savefig may not work!

# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# Set x limits
plt.xlim(-4.0,4.0)

# Set x ticks
plt.xticks(np.linspace(-4,4,9,endpoint=True))

# Set y limits
plt.ylim(-1.0,1.0)

# Set y ticks
plt.yticks(np.linspace(-1,1,5,endpoint=True))



# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# Set x limits
#plt.xlim(-4.0,4.0)
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set x ticks
plt.xticks(np.linspace(-4,4,9,endpoint=True))

# Set y limits
#plt.ylim(-1.0,1.0)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set y ticks
plt.yticks(np.linspace(-1,1,5,endpoint=True))



# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# Set x limits
#plt.xlim(-4.0,4.0)
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set x ticks
#plt.xticks(np.linspace(-4,4,9,endpoint=True))
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# Set y limits
#plt.ylim(-1.0,1.0)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))
plt.yticks([-1, 0, +1])


# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# Set x limits
#plt.xlim(-4.0,4.0)
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set x ticks
#plt.xticks(np.linspace(-4,4,9,endpoint=True))
#plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
#plt.yticks([-1, 0, +1])
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

# Set y limits
#plt.ylim(-1.0,1.0)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))
#plt.yticks([-1, 0, +1])
plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])


# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")

# Set x limits
#plt.xlim(-4.0,4.0)
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set x ticks
#plt.xticks(np.linspace(-4,4,9,endpoint=True))
#plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
#plt.yticks([-1, 0, +1])
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

# Set y limits
#plt.ylim(-1.0,1.0)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))
#plt.yticks([-1, 0, +1])
plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

ax = plt.gca()
ax.spines['right'].set_color('blue')
ax.spines['top'].set_color('red')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))


# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
#plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
#plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

# Set x limits
#plt.xlim(-4.0,4.0)
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set x ticks
#plt.xticks(np.linspace(-4,4,9,endpoint=True))
#plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
#plt.yticks([-1, 0, +1])
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

# Set y limits
#plt.ylim(-1.0,1.0)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))
#plt.yticks([-1, 0, +1])
plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

ax = plt.gca()
ax.spines['right'].set_color('blue')
ax.spines['top'].set_color('red')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.legend(loc='upper left', frameon=False)


# Show result on screen
plt.show()

# %%
# Create a new figure of size 8x6 points, using 100 dots per inch
#plt.figure(figsize=(8,6), dpi=80)
plt.figure(figsize=(10,6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(111)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# Plot cosine using blue color with a continuous line of width 1 (pixels)
#plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-")
#plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")

# Plot sine using green color with a continuous line of width 1 (pixels)
#plt.plot(X, S, color="green", linewidth=1.0, linestyle="-")
#plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

# Set x limits
#plt.xlim(-4.0,4.0)
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set x ticks
#plt.xticks(np.linspace(-4,4,9,endpoint=True))
#plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
#plt.yticks([-1, 0, +1])
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

# Set y limits
#plt.ylim(-1.0,1.0)
plt.ylim(C.min()*1.1, C.max()*1.1)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))
#plt.yticks([-1, 0, +1])
plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])

ax = plt.gca()
ax.spines['right'].set_color('blue')
ax.spines['top'].set_color('red')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.legend(loc='upper left', frameon=False)


t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color ='blue', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.cos(t),], 50, color ='blue')

plt.annotate(r'$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t,t],[0,np.sin(t)], color ='red', linewidth=1.5, linestyle="--")
plt.scatter([t,],[np.sin(t),], 50, color ='red')

plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

# Show result on screen
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap='jet')
C = plt.contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   s)

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T = np.arctan2(Y,X)

plt.axes([0.025,0.025,0.95,0.95])
plt.scatter(X,Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5,1.5), plt.xticks([])
plt.ylim(-1.5,1.5), plt.yticks([])
# savefig('../figures/scatter_ex.png',dpi=48)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.axes([0.025,0.025,0.95,0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x,y in zip(X,Y2):
    plt.text(x+0.4, -y-0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5,n), plt.xticks([])
plt.ylim(-1.25,+1.25), plt.yticks([])

# savefig('../figures/bar_ex.png', dpi=48)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x,y):
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.axes([0.025,0.025,0.95,0.95])

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap=plt.cm.hot)
C = plt.contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([]), plt.yticks([])
# savefig('../figures/contour_ex.png',dpi=48)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   s)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.hot)
ax.contourf(X, Y, Z, zdir='z', offset=-2, cmap=plt.cm.hot)
ax.set_zlim(-2,2)

# savefig('../figures/plot3d_ex.png',dpi=48)
plt.show()

# %% [markdown]
# # Tutorial 2

# %%
# !wget http://qrc.depaul.edu/Excel_Files/Presidents.xls
# Out:
# --2018-09-03 10:17:59--  http://qrc.depaul.edu/Excel_Files/Presidents.xls
# Resolving qrc.depaul.edu (qrc.depaul.edu)... 216.220.178.181
# Connecting to qrc.depaul.edu (qrc.depaul.edu)|216.220.178.181|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50176 (49K) [application/vnd.ms-excel]
# Saving to: ‘Presidents.xls’
#
# Presidents.xls      100%[===================>]  49.00K  --.-KB/s    in 0.1s
#
# 2018-09-03 10:17:59 (346 KB/s) - ‘Presidents.xls’ saved [50176/50176]

# %%
# required for the next command to convert xls to csv
# !apt-get install gnumeric
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   adwaita-icon-theme aspell aspell-en at-spi2-core bsdmainutils dbus
#   dbus-user-session dconf-gsettings-backend dconf-service dictionaries-common
#   dmsetup emacsen-common enchant evince evince-common fontconfig
#   fonts-droid-fallback fonts-noto-mono glib-networking glib-networking-common
#   glib-networking-services gnome-desktop3-data gnumeric-common gnumeric-doc
#   groff-base gsettings-desktop-schemas gsfonts gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache
#   hicolor-icon-theme humanity-icon-theme hunspell-en-us iso-codes libaa1
#   libapparmor1 libarchive13 libaspell15 libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libavahi-client3 libavahi-common-data
#   libavahi-common3 libavc1394-0 libboost-filesystem1.62.0
#   libboost-system1.62.0 libcaca0 libcairo-gobject2 libcairo2 libcap2
#   libcap2-bin libcapnp-0.5.3 libcdparanoia0 libcolamd2 libcolord2 libcroco3
#   libcryptsetup4 libcups2 libcupsfilters1 libcupsimage2 libdatrie1 libdbus-1-3
#   libdconf1 libdevmapper1.02.1 libdjvulibre-text libdjvulibre21 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libdv4
#   libegl1-mesa libelf1 libenchant1c2a libepoxy0 libevdocument3-4 libevview3-3
#   libflac8 libgbm1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa
#   libgnome-desktop-3-12 libgoffice-0.10-10 libgoffice-0.10-10-common libgpm2
#   libgraphite2-3 libgs9 libgs9-common libgsf-1-114 libgsf-1-common
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0
#   libgxps2 libharfbuzz-icu0 libharfbuzz0b libhunspell-1.6-0 libhyphen0
#   libiec61883-0 libijs-0.35 libip4tc0 libjack-jackd2-0
#   libjavascriptcoregtk-4.0-18 libjbig0 libjbig2dec0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libkmod2 libkpathsea6 liblcms2-2 libllvm5.0
#   liblzo2-2 libmirclient9 libmircommon7 libmircore1 libmirprotobuf3
#   libnautilus-extension1a libnotify4 libnspr4 libnss3 libogg0 libopus0
#   liborc-0.4-0 libpam-cap libpam-systemd libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpaper-utils libpaper1 libpciaccess0 libpipeline1
#   libpixman-1-0 libpoppler-glib8 libpoppler68 libprotobuf-lite10 libproxy1v5
#   libraw1394-11 librest-0.7-0 librsvg2-2 librsvg2-common libsamplerate0
#   libseccomp2 libsecret-1-0 libsecret-common libsensors4 libshout3 libslang2
#   libsoup-gnome2.4-1 libsoup2.4-1 libspectre1 libspeex1 libsuitesparseconfig4
#   libtag1v5 libtag1v5-vanilla libtext-iconv-perl libthai-data libthai0
#   libtheora0 libtiff5 libtxc-dxtn-s2tc libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvorbis0a libvorbisenc2 libvpx4 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1-mesa libwayland-server0
#   libwebkit2gtk-4.0-37 libwebp6 libwebpdemux2 libx11-xcb1 libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-render0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcomposite1 libxcursor1 libxdamage1
#   libxfixes3 libxi6 libxinerama1 libxkbcommon0 libxrandr2 libxshmfence1
#   libxslt1.1 libxtst6 libxv1 libxxf86vm1 libyelp0 lp-solve man-db
#   notification-daemon poppler-data pxlib1 shared-mime-info systemd
#   systemd-sysv ubuntu-mono xkb-data yelp yelp-xsl
# Suggested packages:
#   aspell-doc spellutils wamerican | wordlist whois vacation wordlist gvfs
#   nautilus-sendto unrar fonts-noto gnumeric-plugins-extra docbook-xsl groff
#   hunspell openoffice.org-hunspell | openoffice.org-core isoquery lrzip colord
#   cups-common libdv-bin oss-compat libenchant-voikko gpm libvisual-0.4-plugins
#   gstreamer1.0-tools jackd2 liblcms2-utils opus-tools pciutils libraw1394-doc
#   librsvg2-bin lm-sensors speex libwebkit2gtk-4.0-37-gtk2 less www-browser
#   poppler-utils ghostscript fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum systemd-container policykit-1
# The following NEW packages will be installed:
#   adwaita-icon-theme aspell aspell-en at-spi2-core bsdmainutils dbus
#   dbus-user-session dconf-gsettings-backend dconf-service dictionaries-common
#   dmsetup emacsen-common enchant evince evince-common fontconfig
#   fonts-droid-fallback fonts-noto-mono glib-networking glib-networking-common
#   glib-networking-services gnome-desktop3-data gnumeric gnumeric-common
#   gnumeric-doc groff-base gsettings-desktop-schemas gsfonts
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good gstreamer1.0-x
#   gtk-update-icon-cache hicolor-icon-theme humanity-icon-theme hunspell-en-us
#   iso-codes libaa1 libapparmor1 libarchive13 libaspell15 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavc1394-0 libboost-filesystem1.62.0
#   libboost-system1.62.0 libcaca0 libcairo-gobject2 libcairo2 libcap2
#   libcap2-bin libcapnp-0.5.3 libcdparanoia0 libcolamd2 libcolord2 libcroco3
#   libcryptsetup4 libcups2 libcupsfilters1 libcupsimage2 libdatrie1 libdbus-1-3
#   libdconf1 libdevmapper1.02.1 libdjvulibre-text libdjvulibre21 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libdv4
#   libegl1-mesa libelf1 libenchant1c2a libepoxy0 libevdocument3-4 libevview3-3
#   libflac8 libgbm1 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa
#   libgnome-desktop-3-12 libgoffice-0.10-10 libgoffice-0.10-10-common libgpm2
#   libgraphite2-3 libgs9 libgs9-common libgsf-1-114 libgsf-1-common
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgudev-1.0-0
#   libgxps2 libharfbuzz-icu0 libharfbuzz0b libhunspell-1.6-0 libhyphen0
#   libiec61883-0 libijs-0.35 libip4tc0 libjack-jackd2-0
#   libjavascriptcoregtk-4.0-18 libjbig0 libjbig2dec0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libkmod2 libkpathsea6 liblcms2-2 libllvm5.0
#   liblzo2-2 libmirclient9 libmircommon7 libmircore1 libmirprotobuf3
#   libnautilus-extension1a libnotify4 libnspr4 libnss3 libogg0 libopus0
#   liborc-0.4-0 libpam-cap libpam-systemd libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpaper-utils libpaper1 libpciaccess0 libpipeline1
#   libpixman-1-0 libpoppler-glib8 libpoppler68 libprotobuf-lite10 libproxy1v5
#   libraw1394-11 librest-0.7-0 librsvg2-2 librsvg2-common libsamplerate0
#   libseccomp2 libsecret-1-0 libsecret-common libsensors4 libshout3 libslang2
#   libsoup-gnome2.4-1 libsoup2.4-1 libspectre1 libspeex1 libsuitesparseconfig4
#   libtag1v5 libtag1v5-vanilla libtext-iconv-perl libthai-data libthai0
#   libtheora0 libtiff5 libtxc-dxtn-s2tc libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvorbis0a libvorbisenc2 libvpx4 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1-mesa libwayland-server0
#   libwebkit2gtk-4.0-37 libwebp6 libwebpdemux2 libx11-xcb1 libxcb-dri2-0
#   libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-render0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcomposite1 libxcursor1 libxdamage1
#   libxfixes3 libxi6 libxinerama1 libxkbcommon0 libxrandr2 libxshmfence1
#   libxslt1.1 libxtst6 libxv1 libxxf86vm1 libyelp0 lp-solve man-db
#   notification-daemon poppler-data pxlib1 shared-mime-info systemd
#   systemd-sysv ubuntu-mono xkb-data yelp yelp-xsl
# 0 upgraded, 224 newly installed, 0 to remove and 0 not upgraded.
# Need to get 105 MB of archives.
# After this operation, 513 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libapparmor1 amd64 2.11.0-2ubuntu17.1 [28.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 libcap2 amd64 1:2.25-1.1 [13.2 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 libdevmapper1.02.1 amd64 2:1.02.137-2ubuntu3 [135 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libcryptsetup4 amd64 2:1.7.3-4ubuntu1 [77.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libip4tc0 amd64 1.6.1-2ubuntu1 [19.6 kB]
# Get:6 http://archive.ubuntu.com/ubunt
http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgtk-3-bin amd64 3.22.25-0ubuntu0.1 [57.6 kB]
# Get:221 http://archive.ubuntu.com/ubuntu artful/main amd64 libpaper-utils amd64 1.1.24+nmu5ubuntu1 [8,170 B]
# Get:222 http://archive.ubuntu.com/ubuntu artful/main amd64 lp-solve amd64 5.5.0.15-4build1 [283 kB]
# Get:223 http://archive.ubuntu.com/ubuntu artful/main amd64 notification-daemon amd64 3.20.0-1 [30.2 kB]
# Get:224 http://archive.ubuntu.com/ubuntu artful/main amd64 libtxc-dxtn-s2tc amd64 1.0+git20151227-2 [48.4 kB]
# Fetched 105 MB in 27s (3,834 kB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package libapparmor1:amd64.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../0-libapparmor1_2.11.0-2ubuntu17.1_amd64.deb ...
# Unpacking libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Selecting previously unselected package libcap2:amd64.
# Preparing to unpack .../1-libcap2_1%3a2.25-1.1_amd64.deb ...
# Unpacking libcap2:amd64 (1:2.25-1.1) ...
# Selecting previously unselected package libdevmapper1.02.1:amd64.
# Preparing to unpack .../2-libdevmapper1.02.1_2%3a1.02.137-2ubuntu3_amd64.deb ...
# Unpacking libdevmapper1.02.1:amd64 (2:1.02.137-2ubuntu3) ...
# Selecting previously unselected package libcryptsetup4:amd64.
# Preparing to unpack .../3-libcryptsetup4_2%3a1.7.3-4ubuntu1_amd64.deb ...
# Unpacking libcryptsetup4:amd64 (2:1.7.3-4ubuntu1) ...
# Selecting previously unselected package libip4tc0:amd64.
# Preparing to unpack .../4-libip4tc0_1.6.1-2ubuntu1_amd64.deb ...
# Unpacking libip4tc0:amd64 (1.6.1-2ubuntu1) ...
# Selecting previously unselected package libkmod2:amd64.
# Preparing to unpack .../5-libkmod2_24-1ubuntu2_amd64.deb ...
# Unpacking libkmod2:amd64 (24-1ubuntu2) ...
# Selecting previously unselected package libseccomp2:amd64.
# Preparing to unpack .../6-libseccomp2_2.3.1-2.1ubuntu3_amd64.deb ...
# Unpacking libseccomp2:amd64 (2.3.1-2.1ubuntu3) ...
# Selecting previously unselected package systemd.
# Preparing to unpack .../7-systemd_234-2ubuntu12.4_amd64.deb ...
# Unpacking systemd (234-2ubuntu12.4) ...
# Setting up libapparmor1:amd64 (2.11.0-2ubuntu17.1) ...
# Setting up libcap2:amd64 (1:2.25-1.1) ...
# Setting up libdevmapper1.02.1:amd64 (2:1.02.137-2ubuntu3) ...
# Setting up libcryptsetup4:amd64 (2:1.7.3-4ubuntu1) ...
# Setting up libip4tc0:amd64 (1.6.1-2ubuntu1) ...
# Setting up libkmod2:amd64 (24-1ubuntu2) ...
# Setting up libseccomp2:amd64 (2.3.1-2.1ubuntu3) ...
# Setting up systemd (234-2ubuntu12.4) ...
# Created symlink /etc/systemd/system/getty.target.wants/getty@tty1.service → /lib/systemd/system/getty@.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/remote-fs.target → /lib/systemd/system/remote-fs.target.
# Created symlink /etc/systemd/system/sysinit.target.wants/systemd-timesyncd.service → /lib/systemd/system/systemd-timesyncd.service.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.resolve1.service → /lib/systemd/system/systemd-resolved.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/systemd-resolved.service → /lib/systemd/system/systemd-resolved.service.
# ln: cannot remove '/etc/resolv.conf': Device or resource busy
# Created symlink /etc/systemd/system/multi-user.target.wants/ondemand.service → /lib/systemd/system/ondemand.service.
# Initializing machine ID from random generator.
# Adding group `systemd-journal' (GID 102) ...
# Done.
# Selecting previously unselected package systemd-sysv.
# (Reading database ... 19128 files and directories currently installed.)
# Preparing to unpack .../000-systemd-sysv_234-2ubuntu12.4_amd64.deb ...
# Unpacking systemd-sysv (234-2ubuntu12.4) ...
# Selecting previously unselected package groff-base.
# Preparing to unpack .../001-groff-base_1.22.3-9_amd64.deb ...
# Unpacking groff-base (1.22.3-9) ...
# Selecting previously unselected package bsdmainutils.
# Preparing to unpack .../002-bsdmainutils_9.0.12+nmu1ubuntu1_amd64.deb ...
# Unpacking bsdmainutils (9.0.12+nmu1ubuntu1) ...
# Selecting previously unselected package libpipeline1:amd64.
# Preparing to unpack .../003-libpipeline1_1.4.2-1_amd64.deb ...
# Unpacking libpipeline1:amd64 (1.4.2-1) ...
# Selecting previously unselected package man-db.
# Preparing to unpack .../004-man-db_2.7.6.1-2_amd64.deb ...
# Unpacking man-db (2.7.6.1-2) ...
# Selecting previously unselected package fontconfig.
# Preparing to unpack .../005-fontconfig_2.11.94-0ubuntu2_amd64.deb ...
# Unpacking fontconfig (2.11.94-0ubuntu2) ...
# Selecting previously unselected package fonts-droid-fallback.
# Preparing to unpack .../006-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../007-libdconf1_0.26.0-2_amd64.deb ...
# Unpacking libdconf1:amd64 (0.26.0-2) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../008-dconf-service_0.26.0-2_amd64.deb ...
# Unpacking dconf-service (0.26.0-2) ...
# Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../009-dconf-gsettings-backend_0.26.0-2_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.26.0-2) ...
# Selecting previously unselected package gnumeric-common.
# Preparing to unpack .../010-gnumeric-common_1.12.32-1build2_all.deb ...
# Unpacking gnumeric-common (1.12.32-1build2) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../011-libatk1.0-data_2.26.0-2ubuntu1_all.deb ...
# Unpacking libatk1.0-data (2.26.0-2ubuntu1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../012-libatk1.0-0_2.26.0-2ubuntu1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.26.0-2ubuntu1) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../013-libpixman-1-0_0.34.0-1_amd64.deb ...
# Unpacking libpixman-1-0:amd64 (0.34.0-1) ...
# Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../014-libxcb-render0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../015-libxcb-shm0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../016-libcairo2_1.14.10-1ubuntu1_amd64.deb ...
# Unpacking libcairo2:amd64 (1.14.10-1ubuntu1) ...
# Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../017-libjbig0_2.1-3.1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../018-libtiff5_4.0.8-5ubuntu0.1_amd64.deb ...
# Unpacking libtiff5:amd64 (4.0.8-5ubuntu0.1) ...
# Selecting previously unselected package shared-mime-info.
# Preparing to unpack .../019-shared-mime-info_1.8-1_amd64.deb ...
# Unpacking shared-mime-info (1.8-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../020-libgdk-pixbuf2.0-common_2.36.11-1ubuntu0.1_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.36.11-1ubuntu0.1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../021-libgdk-pixbuf2.0-0_2.36.11-1ubuntu0.1_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.36.11-1ubuntu0.1) ...
# Selecting previously unselected package libgsf-1-common.
# Preparing to unpack .../022-libgsf-1-common_1.14.41-1_all.deb ...
# Unpacking libgsf-1-common (1.14.41-1) ...
# Selecting previously unselected package libgsf-1-114:amd64.
# Preparing to unpack .../023-libgsf-1-114_1.14.41-1_amd64.deb ...
# Unpacking libgsf-1-114:amd64 (1.14.41-1) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../024-libgtk-3-common_3.22.25-0ubuntu0.1_all.deb ...
# Unpacking libgtk-3-common (3.22.25-0ubuntu0.1) ...
# Selecting previously unselected package libdbus-1-3:amd64.
# Preparing to unpack .../025-libdbus-1-3_1.10.22-1ubuntu1_amd64.deb ...
# Unpacking libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../026-libatspi2.0-0_2.26.0-2_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.26.0-2) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../027-libatk-bridge2.0-0_2.26.0-1ubuntu1_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.26.0-1ubuntu1) ...
# Selecting previously unselected package libcairo-gobject2:amd64.
# Preparing to unpack .../028-libcairo-gobject2_1.14.10-1ubuntu1_amd64.deb ...
# Unpacking libcairo-gobject2:amd64 (1.14.10-1ubuntu1) ...
# Selecting previously unselected package liblcms2-2:amd64.
# Preparing to unpack .../029-liblcms2-2_2.7-1ubuntu1_amd64.deb ...
# Unpacking liblcms2-2:amd64 (2.7-1ubuntu1) ...
# Selecting previously unselected package libcolord2:amd64.
# Preparing to unpack .../030-libcolord2_1.3.3-2build1_amd64.deb ...
# Unpacking libcolord2:amd64 (1.3.3-2build1) ...
# Selecting previously unselected package libavahi-common-data:amd64.
# Preparing to unpack .../031-libavahi-common-data_0.6.32-1ubuntu1.1_amd64.deb ...
# Unpacking libavahi-common-data:amd64 (0.6.32-1ubuntu1.1) ...
# Selecting previously unselected package libavahi-common3:amd64.
# Preparing to unpack .../032-libavahi-common3_0.6.32-1ubuntu1.1_amd64.deb ...
# Unpacking libavahi-common3:amd64 (0.6.32-1ubuntu1.1) ...
# Selecting previously unselected package libavahi-client3:amd64.
# Preparing to unpack .../033-libavahi-client3_0.6.32-1ubuntu1.1_amd64.deb ...
# Unpacking libavahi-client3:amd64 (0.6.32-1ubuntu1.1) ...
# Selecting previously unselected package libcups2:amd64.
# Preparing to unpack .../034-libcups2_2.2.4-7ubuntu3.1_amd64.deb ...
# Unpacking libcups2:amd64 (2.2.4-7ubuntu3.1) ...
# Selecting previously unselected package libepoxy0:amd64.
# Preparing to unpack .../035-libepoxy0_1.3.1-3_amd64.deb ...
# Unpacking libepoxy0:amd64 (1.3.1-3) ...
# Selecting previously unselected package libjson-glib-1.0-common.
# Preparing to unpack .../036-libjson-glib-1.0-common_1.2.8-1_all.deb ...
# Unpacking libjson-glib-1.0-common (1.2.8-1) ...
# Selecting previously unselected package libjson-glib-1.0-0:amd64.
# Preparing to unpack .../037-libjson-glib-1.0-0_1.2.8-1_amd64.deb ...
# Unpacking libjson-glib-1.0-0:amd64 (1.2.8-1) ...
# Selecting previously unselected package libboost-system1.62.0:amd64.
# Preparing to unpack .../038-libboost-system1.62.0_1.62.0+dfsg-4build3_amd64.deb ...
# Unpacking libboost-system1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Selecting previously unselected package libcapnp-0.5.3:amd64.
# Preparing to unpack .../039-libcapnp-0.5.3_0.5.3-2ubuntu2_amd64.deb ...
# Unpacking libcapnp-0.5.3:amd64 (0.5.3-2ubuntu2) ...
# Selecting previously unselected package libboost-filesystem1.62.0:amd64.
# Preparing to unpack .../040-libboost-filesystem1.62.0_1.62.0+dfsg-4build3_amd64.deb ...
# Unpacking libboost-filesystem1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../041-libmircore1_0.28.0+17.10.20171011.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../042-libmircommon7_0.28.0+17.10.20171011.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../043-libprotobuf-lite10_3.0.0-9ubuntu5_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9ubuntu5) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../044-libmirprotobuf3_0.28.0+17.10.20171011.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Selecting previously unselected package xkb-data.
# Preparing to unpack .../045-xkb-data_2.19-1.1ubuntu1_all.deb ...
# Unpacking xkb-data (2.19-1.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon0:amd64.
# Preparing to unpack .../046-libxkbcommon0_0.7.1-2_amd64.deb ...
# Unpacking libxkbcommon0:amd64 (0.7.1-2) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../047-libmirclient9_0.28.0+17.10.20171011.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../048-libthai-data_0.1.26-3_all.deb ...
# Unpacking libthai-data (0.1.26-3) ...
# Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../049-libdatrie1_0.2.10-5_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.10-5) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../050-libthai0_0.1.26-3_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.26-3) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../051-libpango-1.0-0_1.40.12-1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.40.12-1) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../052-libgraphite2-3_1.3.10-2_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.10-2) ...
# Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../053-libharfbuzz0b_1.4.2-1_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (1.4.2-1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../054-libpangoft2-1.0-0_1.40.12-1_amd64.deb ...
# Unpacking libpangoft2-1.0-0:amd64 (1.40.12-1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../055-libpangocairo-1.0-0_1.40.12-1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.40.12-1) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../056-libproxy1v5_0.4.14-3_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.14-3) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../057-glib-networking-common_2.54.0-1_all.deb ...
# Unpacking glib-networking-common (2.54.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../058-glib-networking-services_2.54.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.54.0-1) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../059-gsettings-desktop-schemas_3.24.1-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (3.24.1-1ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../060-glib-networking_2.54.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.54.0-1) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../061-libsoup2.4-1_2.60.1-1ubuntu0.1_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.60.1-1ubuntu0.1) ...
# Selecting previously unselected package libsoup-gnome2.4-1:amd64.
# Preparing to unpack .../062-libsoup-gnome2.4-1_2.60.1-1ubuntu0.1_amd64.deb ...
# Unpacking libsoup-gnome2.4-1:amd64 (2.60.1-1ubuntu0.1) ...
# Selecting previously unselected package librest-0.7-0:amd64.
# Preparing to unpack .../063-librest-0.7-0_0.8.0-2_amd64.deb ...
# Unpacking librest-0.7-0:amd64 (0.8.0-2) ...
# Selecting previously unselected package libwayland-client0:amd64.
# Preparing to unpack .../064-libwayland-client0_1.14.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-client0:amd64 (1.14.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-cursor0:amd64.
# Preparing to unpack .../065-libwayland-cursor0_1.14.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-cursor0:amd64 (1.14.0-1ubuntu0.1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../066-libdrm-common_2.4.83-1_all.deb ...
# Unpacking libdrm-common (2.4.83-1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../067-libdrm2_2.4.83-1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.83-1) ...
# Selecting previously unselected package libwayland-server0:amd64.
# Preparing to unpack .../068-libwayland-server0_1.14.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-server0:amd64 (1.14.0-1ubuntu0.1) ...
# Selecting previously unselected package libgbm1:amd64.
# Preparing to unpack .../069-libgbm1_17.2.8-0ubuntu0~17.10.1_amd64.deb ...
# Unpacking libgbm1:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Selecting previously unselected package libx11-xcb1:amd64.
# Preparing to unpack .../070-libx11-xcb1_2%3a1.6.4-3_amd64.deb ...
# Unpacking libx11-xcb1:amd64 (2:1.6.4-3) ...
# Selecting previously unselected package libxcb-dri2-0:amd64.
# Preparing to unpack .../071-libxcb-dri2-0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-dri2-0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-dri3-0:amd64.
# Preparing to unpack .../072-libxcb-dri3-0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-dri3-0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-present0:amd64.
# Preparing to unpack .../073-libxcb-present0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-present0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-sync1:amd64.
# Preparing to unpack .../074-libxcb-sync1_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../075-libxcb-xfixes0_1.12-1ubuntu1_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.12-1ubuntu1) ...
# Selecting previously unselected package libxshmfence1:amd64.
# Preparing to unpack .../076-libxshmfence1_1.2-1_amd64.deb ...
# Unpacking libxshmfence1:amd64 (1.2-1) ...
# Selecting previously unselected package libdrm-amdgpu1:amd64.
# Preparing to unpack .../077-libdrm-amdgpu1_2.4.83-1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.83-1) ...
# Selecting previously unselected package libpciaccess0:amd64.
# ...
# Unpacking libv4lconvert0:amd64 (1.12.5-1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../202-libv4l-0_1.12.5-1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.12.5-1) ...
# Selecting previously unselected package libvpx4:amd64.
# Preparing to unpack .../203-libvpx4_1.6.1-3_amd64.deb ...
# Unpacking libvpx4:amd64 (1.6.1-3) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../204-libwavpack1_5.1.0-2ubuntu0.3_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.1.0-2ubuntu0.3) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../205-gstreamer1.0-plugins-good_1.12.3-1ubuntu1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.12.3-1ubuntu1) ...
# Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../206-libxv1_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv1:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../207-gstreamer1.0-x_1.12.3-1_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.12.3-1) ...
# Selecting previously unselected package libsuitesparseconfig4:amd64.
# Preparing to unpack .../208-libsuitesparseconfig4_1%3a4.5.5-1_amd64.deb ...
# Unpacking libsuitesparseconfig4:amd64 (1:4.5.5-1) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../209-libcolamd2_1%3a4.5.5-1_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:4.5.5-1) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../210-libcupsfilters1_1.17.9-0ubuntu1.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.17.9-0ubuntu1.1) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../211-libgtk-3-bin_3.22.25-0ubuntu0.1_amd64.deb ...
# Unpacking libgtk-3-bin (3.22.25-0ubuntu0.1) ...
# Selecting previously unselected package libpaper-utils.
# Preparing to unpack .../212-libpaper-utils_1.1.24+nmu5ubuntu1_amd64.deb ...
# Unpacking libpaper-utils (1.1.24+nmu5ubuntu1) ...
# Selecting previously unselected package lp-solve.
# Preparing to unpack .../213-lp-solve_5.5.0.15-4build1_amd64.deb ...
# Unpacking lp-solve (5.5.0.15-4build1) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../214-notification-daemon_3.20.0-1_amd64.deb ...
# Unpacking notification-daemon (3.20.0-1) ...
# Selecting previously unselected package libtxc-dxtn-s2tc:amd64.
# Preparing to unpack .../215-libtxc-dxtn-s2tc_1.0+git20151227-2_amd64.deb ...
# Unpacking libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# Setting up libgs9-common (9.21~dfsg+1-0ubuntu3.1) ...
# Setting up libxi6:amd64 (2:1.7.9-1) ...
# Setting up libkpathsea6:amd64 (2017.20170613.44572-5build1) ...
# Setting up libpaper1:amd64 (1.1.24+nmu5ubuntu1) ...
#
# Creating config file /etc/papersize with new version
# Setting up libxcb-present0:amd64 (1.12-1ubuntu1) ...
# Setting up libxinerama1:amd64 (2:1.1.3-1) ...
# Setting up libxcb-dri2-0:amd64 (1.12-1ubuntu1) ...
# Setting up libsecret-common (0.18.5-3.1ubuntu2) ...
# Setting up libxcb-dri3-0:amd64 (1.12-1ubuntu1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libxcb-glx0:amd64 (1.12-1ubuntu1) ...
# Setting up libpaper-utils (1.1.24+nmu5ubuntu1) ...
# Setting up libraw1394-11:amd64 (2.1.2-1) ...
# Setting up libjson-glib-1.0-common (1.2.8-1) ...
# Setting up libxcb-xfixes0:amd64 (1.12-1ubuntu1) ...
# Setting up libxcb-render0:amd64 (1.12-1ubuntu1) ...
# Setting up libpam-cap:amd64 (1:2.25-1.1) ...
# Setting up glib-networking-common (2.54.0-1) ...
# Setting up libxdamage1:amd64 (1:1.1.4-3) ...
# Setting up libxfixes3:amd64 (1:5.0.3-1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.3) ...
# Setting up iso-codes (3.75-1) ...
# Setting up libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Setting up libwavpack1:amd64 (5.1.0-2ubuntu0.3) ...
# Setting up liblcms2-2:amd64 (2.7-1ubuntu1) ...
# Setting up libjbig0:amd64 (2.1-3.1) ...
# Setting up libgpm2:amd64 (1.20.4-6.2) ...
# Setting up libaspell15:amd64 (0.60.7~20110707-4) ...
# Setting up poppler-data (0.4.8-1) ...
# Setting up libdjvulibre-text (3.5.27.1-7) ...
# Setting up libcap2-bin (1:2.25-1.1) ...
# Setting up systemd-sysv (234-2ubuntu12.4) ...
# Setting up libv4lconvert0:amd64 (1.12.5-1) ...
# Setting up libelf1:amd64 (0.170-0.1) ...
# Setting up libgsf-1-common (1.14.41-1) ...
# Setting up groff-base (1.22.3-9) ...
# Processing triggers for libglib2.0-0:amd64 (2.54.1-1ubuntu1) ...
# Setting up libxshmfence1:amd64 (1.2-1) ...
# Setting up emacsen-common (2.0.8) ...
# Setting up libwayland-client0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up xkb-data (2.19-1.1ubuntu1) ...
# Setting up libproxy1v5:amd64 (0.4.14-3) ...
# Setting up libcapnp-0.5.3:amd64 (0.5.3-2ubuntu2) ...
# Setting up libsuitesparseconfig4:amd64 (1:4.5.5-1) ...
# Setting up libgdk-pixbuf2.0-common (2.36.11-1ubuntu0.1) ...
# Setting up libllvm5.0:amd64 (1:5.0-3) ...
# Setting up glib-networking-services (2.54.0-1) ...
# Setting up libdatrie1:amd64 (0.2.10-5) ...
# Setting up libtiff5:amd64 (4.0.8-5ubuntu0.1) ...
# Setting up libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/s2tc/libtxc_dxtn.so to provide /usr/lib/x86_64-linux-gnu/libtxc_dxtn.so (libtxc-dxtn-x86_64-linux-gnu) in auto mode
# Setting up libpipeline1:amd64 (1.4.2-1) ...
# Setting up libgsf-1-114:amd64 (1.14.41-1) ...
# Setting up libiec61883-0:amd64 (1.2.0-2) ...
# Setting up libglapi-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1ubuntu1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-11) ...
# Setting up libnspr4:amd64 (2:4.16-1ubuntu2) ...
# Setting up libvpx4:amd64 (1.6.1-3) ...
# Setting up libopus0:amd64 (1.1.2-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up fonts-noto-mono (20161116-1) ...
# Setting up evince-common (3.26.0-1) ...
# Setting up libdrm-common (2.4.83-1) ...
# Setting up libjson-glib-1.0-0:amd64 (1.2.8-1) ...
# Setting up libgraphite2-3:amd64 (1.3.10-2) ...
# Setting up libcroco3:amd64 (0.6.12-1) ...
# Setting up libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Setting up libxslt1.1:amd64 (1.1.29-2.1ubuntu1) ...
# Setting up libogg0:amd64 (1.3.2-1) ...
# Setting up libatk1.0-data (2.26.0-2ubuntu1) ...
# Setting up libjbig2dec0:amd64 (0.13-5) ...
# Setting up libhyphen0:amd64 (2.8.8-5) ...
# Setting up libx11-xcb1:amd64 (2:1.6.4-3) ...
# Setting up libpixman-1-0:amd64 (0.34.0-1) ...
# Setting up libxcursor1:amd64 (1:1.1.14-3ubuntu0.1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libepoxy0:amd64 (1.3.1-3) ...
# Setting up libatk1.0-0:amd64 (2.26.0-2ubuntu1) ...
# Setting up libtext-iconv-perl (1.7-5build6) ...
# Setting up libgoffice-0.10-10-common (0.10.32-1.1) ...
# Processing triggers for systemd (234-2ubuntu12.4) ...
# Setting up libavc1394-0:amd64 (0.5.4-4) ...
# Setting up libijs-0.35:amd64 (0.35-12) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-10) ...
# Setting up libcolamd2:amd64 (1:4.5.5-1) ...
# Setting up libdconf1:amd64 (0.26.0-2) ...
# Setting up libxcomposite1:amd64 (1:0.4.4-2) ...
# Setting up libxcb-shm0:amd64 (1.12-1ubuntu1) ...
# Setting up dmsetup (2:1.02.137-2ubuntu3) ...
# Setting up libpciaccess0:amd64 (0.13.4-1ubuntu1) ...
# Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libsensors4:amd64 (1:3.4.0-4) ...
# Setting up shared-mime-info (1.8-1) ...
# Setting up libxkbcommon0:amd64 (0.7.1-2) ...
# Setting up libgudev-1.0-0:amd64 (1:232-1) ...
# Setting up libjavascriptcoregtk-4.0-18:amd64 (2.20.3-0ubuntu0.17.10.1) ...
# Setting up yelp-xsl (3.20.1-2) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.27-1) ...
# Setting up libcolord2:amd64 (1.3.3-2build1) ...
# Setting up libthai-data (0.1.26-3) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1) ...
# Setting up bsdmainutils (9.0.12+nmu1ubuntu1) ...
# update-alternatives: using /usr/bin/bsd-write to provide /usr/bin/write (write) in auto mode
# update-alternatives: using /usr/bin/bsd-from to provide /usr/bin/from (from) in auto mode
# Setting up libsamplerate0:amd64 (0.1.9-1) ...
# Setting up libvorbis0a:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9ubuntu5) ...
# Setting up hicolor-icon-theme (0.17-1) ...
# Setting up libsecret-1-0:amd64 (0.18.5-3.1ubuntu2) ...
# Setting up libslang2:amd64 (2.3.1-5ubuntu1) ...
# Setting up gnome-desktop3-data (3.26.2-0ubuntu0.1) ...
# Setting up libwayland-cursor0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up pxlib1 (0.6.7-1) ...
# Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up libboost-system1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libdv4:amd64 (1.0.0-11) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.2) ...
# Setting up fontconfig (2.11.94-0ubuntu2) ...
# Regenerating fonts cache... done.
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up libavahi-common-data:amd64 (0.6.32-1ubuntu1.1) ...
# Setting up libwayland-server0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up libwebp6:amd64 (0.6.0-3) ...
# Setting up libcairo2:amd64 (1.14.10-1ubuntu1) ...
# Setting up lp-solve (5.5.0.15-4build1) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.2) ...
# Setting up libgstreamer1.0-0:amd64 (1.12.3-1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up libdjvulibre21:amd64 (3.5.27.1-7) ...
# Setting up dconf-service (0.26.0-2) ...
# Setting up libv4l-0:amd64 (1.12.5-1) ...
# Setting up dictionaries-common (1.27.2) ...
# Setting up libarchive13:amd64 (3.2.2-3.1) ...
# Setting up libmirprotobuf3:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libatspi2.0-0:amd64 (2.26.0-2) ...
# Setting up at-spi2-core (2.26.0-2) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-1ubuntu0.1) ...
# Setting up libcairo-gobject2:amd64 (1.14.10-1ubuntu1) ...
# Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-1ubuntu0.1) ...
# Setting up libnss3:amd64 (2:3.32-1ubuntu3) ...
# Setting up libharfbuzz0b:amd64 (1.4.2-1) ...
# Setting up libthai0:amd64 (0.1.26-3) ...
# Setting up libdrm2:amd64 (2.4.83-1) ...
# Setting up libdrm-intel1:amd64 (2.4.83-1) ...
# Setting up gtk-update-icon-cache (3.22.25-0ubuntu0.1) ...
# Setting up libaa1:amd64 (1.4p5-44build1) ...
# Setting up libgxps2:amd64 (0.3.0-1) ...
# Setting up libpango-1.0-0:amd64 (1.40.12-1) ...
# Setting up libboost-filesystem1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libatk-bridge2.0-0:amd64 (2.26.0-1ubuntu1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.10+20150825git1ed50c92~dfsg-5ubuntu1) ...
# Setting up libwebpdemux2:amd64 (0.6.0-3) ...
# Setting up man-db (2.7.6.1-2) ...
# Building database of manual pages ...
# Setting up libavahi-common3:amd64 (0.6.32-1ubuntu1.1) ...
# Setting up libdrm-radeon1:amd64 (2.4.83-1) ...
# Setting up dbus (1.10.22-1ubuntu1) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libdrm-nouveau2:amd64 (2.4.83-1) ...
# Setting up libmircore1:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libcaca0:amd64 (0.99.beta19-2build2~gcc5.2) ...
# Setting up aspell (0.60.7~20110707-4) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libshout3:amd64 (2.3.1-3) ...
# Setting up dconf-gsettings-backend:amd64 (0.26.0-2) ...
# Setting up gnumeric-common (1.12.32-1build2) ...
# Setting up libpoppler68:amd64 (0.57.0-2ubuntu4.3) ...
# Setting up hunspell-en-us (20070829-6ubuntu3) ...
# Setting up libenchant1c2a:amd64 (1.6.0-11build2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.12.3-1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.12.3-1) ...
# Setting up libnotify4:amd64 (0.7.7-2) ...
# Setting up libpoppler-glib8:amd64 (0.57.0-2ubuntu4.3) ...
# Setting up libpam-systemd:amd64 (234-2ubuntu12.4) ...
# Setting up libharfbuzz-icu0:amd64 (1.4.2-1) ...
# Setting up gsettings-desktop-schemas (3.24.1-1ubuntu1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.83-1) ...
# Setting up libgtk-3-common (3.22.25-0ubuntu0.1) ...
# Setting up libgbm1:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libgl1-mesa-dri:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up dbus-user-session (1.10.22-1ubuntu1) ...
# Setting up libpangoft2-1.0-0:amd64 (1.40.12-1) ...
# Setting up libgl1-mesa-glx:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf (x86_64-linux-gnu_gl_conf) in auto mode
# Setting up glib-networking:amd64 (2.54.0-1) ...
# Setting up aspell-en (2017.08.24-0-0.1) ...
# Setting up enchant (1.6.0-11build2) ...
# Setting up libmircommon7:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libavahi-client3:amd64 (0.6.32-1ubuntu1.1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.12.3-1ubuntu1) ...
# Setting up libcups2:amd64 (2.2.4-7ubuntu3.1) ...
# Setting up libsoup2.4-1:amd64 (2.60.1-1ubuntu0.1) ...
# Setting up libsoup-gnome2.4-1:amd64 (2.60.1-1ubuntu0.1) ...
# Setting up libmirclient9:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.40.12-1) ...
# Setting up libcupsfilters1:amd64 (1.17.9-0ubuntu1.1) ...
# Setting up libcupsimage2:amd64 (2.2.4-7ubuntu3.1) ...
# Setting up librest-0.7-0:amd64 (0.8.0-2) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.12.3-1ubuntu1) ...
# Setting up gstreamer1.0-x:amd64 (1.12.3-1) ...
# Setting up libgs9:amd64 (9.21~dfsg+1-0ubuntu3.1) ...
# Setting up libspectre1:amd64 (0.2.8-1) ...
# Setting up libegl1-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/mesa-egl/ld.so.conf to provide /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf (x86_64-linux-gnu_egl_conf) in auto mode
# Setting up librsvg2-2:amd64 (2.40.18-1) ...
# Setting up librsvg2-common:amd64 (2.40.18-1) ...
# Setting up libwayland-egl1-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up adwaita-icon-theme (3.26.0-0ubuntu2) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up humanity-icon-theme (0.6.13) ...
# Setting up libgtk-3-0:amd64 (3.22.25-0ubuntu0.1) ...
# Setting up libgtk-3-bin (3.22.25-0ubuntu0.1) ...
# Setting up libnautilus-extension1a:amd64 (1:3.26.0-0ubuntu1) ...
# Setting up libgoffice-0.10-10 (0.10.32-1.1) ...
# Setting up libgnome-desktop-3-12:amd64 (3.26.2-0ubuntu0.1) ...
# Setting up notification-daemon (3.20.0-1) ...
# Setting up gnumeric (1.12.32-1build2) ...
# Setting up ubuntu-mono (16.10+17.10.20171115-0ubuntu1) ...
# Setting up libwebkit2gtk-4.0-37:amd64 (2.20.3-0ubuntu0.17.10.1) ...
# Setting up libevdocument3-4:amd64 (3.26.0-1) ...
# Setting up libyelp0:amd64 (3.26.0-1ubuntu1) ...
# Setting up libevview3-3:amd64 (3.26.0-1) ...
# Setting up yelp (3.26.0-1ubuntu1) ...
# Setting up evince (3.26.0-1) ...
# Setting up gnumeric-doc (1.12.32-1build2) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Processing triggers for dictionaries-common (1.27.2) ...
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Processing triggers for systemd (234-2ubuntu12.4) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-1ubuntu0.1) ...

# %%
# !ssconvert Presidents.xls Presidents.csv
# Out:
# Selected exporter (Gnumeric_stf:stf_csv) does not support saving multiple sheets in one file.
# Only the current sheet will be saved.  To get around this limitation, use -S.
#
# (ssconvert:11775): dconf-WARNING **: failed to commit changes to dconf: Cannot autolaunch D-Bus without X11 $DISPLAY

# %%
ls -l
# Out:
# total 64
# -rw-r--r-- 1 root root  5669 Sep  3 10:21 Presidents.csv
# -rw-r--r-- 1 root root 50176 Nov 30  2011 Presidents.xls
# drwxr-xr-x 2 root root  4096 Aug 30 21:39 sample_data/

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = 'Presidents.csv'
Presidents_df = pd.read_csv(file)

# %%
# plot data
plt.figure(figsize=(6,6), dpi=80)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','red','green','blue','orange','white','brown']
Presidents_df['Occupation'].value_counts().plot(kind='pie',title='Occupation by President',colors=colors)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 8
X,Y = np.mgrid[0:n,0:n]
plt.quiver(X,Y)
plt.show()

# %%
# !wget https://raw.githubusercontent.com/ourcodingclub/CC-python-pandas-matplotlib/master/scottish_hills.csv
# Out:
# --2018-09-03 10:32:26--  https://raw.githubusercontent.com/ourcodingclub/CC-python-pandas-matplotlib/master/scottish_hills.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14433 (14K) [text/plain]
# Saving to: ‘scottish_hills.csv’
#
# scottish_hills.csv  100%[===================>]  14.09K  --.-KB/s    in 0.006s
#
# 2018-09-03 10:32:27 (2.22 MB/s) - ‘scottish_hills.csv’ saved [14433/14433]

# %%
# !ls -l
# Out:
# total 84
# -rw-r--r-- 1 root root  5669 Sep  3 10:21 Presidents.csv
# -rw-r--r-- 1 root root 50176 Nov 30  2011 Presidents.xls
# drwxr-xr-x 2 root root  4096 Aug 30 21:39 sample_data
# -rw-r--r-- 1 root root 14433 Sep  3 10:32 scottish_hills.csv

# %%
dataframe = pd.read_csv("scottish_hills.csv")

# %%
x = dataframe.Height
y = dataframe.Latitude

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.figure(figsize=(8,8), dpi=80)
plt.scatter(x, y)
plt.show()

# %%
from scipy.stats import linregress

# %%
stats = linregress(x, y)

m = stats.slope
b = stats.intercept

# %%
plt.figure(figsize=(8,8), dpi=80)
plt.scatter(x, y)
plt.plot(x, m * x + b, color="red")   # I've added a color argument here
plt.show()  # or plt.savefig("name.png")

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 20
Z = np.random.uniform(0,1,n)
plt.pie(Z)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.subplot(2,2,1)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

plt.show()
